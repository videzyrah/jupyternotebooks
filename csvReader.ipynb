# %%
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
plt.rcParams['figure.figsize'] = [4, 6]

# %%
csv_to_read='portfolio_9_22_2021.csv'
excel_to_read='portfolio_9_22_2021.xlsx'#for currency type and asset class, do not change 
canadianX = 0.79

# %%
df =  pd.read_csv(csv_to_read)
xldf = pd.read_excel(excel_to_read)
currency_column = xldf["Trading Currency"]
asset_class_column = xldf["Asset Class"]
df['Trading Currency']= currency_column
df['Asset Class']= asset_class_column
df['Market Value'] = df['Market Value'].apply(lambda x: float(x.split()[0].replace(',', '')))
df.filter(items=['Symbol', 'Position', 'Last','Market Value', 'Trading Currency', 'Asset Class' ]).sort_values('Symbol')
# Out:
#    Symbol Position    Last  Market Value Trading Currency Asset Class
# 9     AIG      150   53.88        8082.0              USD       Stock
# 11   AMAT       60  138.11        8288.0              USD       Stock
# 17    AUY    4,900    4.08       19968.0              USD        Gold
# 7      BG      215   77.71       16707.0              USD   Commodity
# 13    CMI       35  221.99        7771.0              USD       Stock
# 8    COPX      170   34.42        5852.0              USD   Commodity
# 12    EWY      165   82.11       13549.0              USD       Stock
# 19    GDX      100   30.51        3052.0              USD        Gold
# 1     GLO   12,900   3.200       40893.0              CAD   Commodity
# 20   GOLD      290   18.43        5345.0              USD        Gold
# 10     KL      915   42.36       38759.0              USD        Gold
# 5     LUN      838   8.970        7521.0              CAD   Commodity
# 2   OGZPY    3,100    9.29       28815.0              USD   Commodity
# 0    PHOR    1,700   20.72       35224.0              USD   Commodity
# 4     RIO      150   66.81       10020.0              USD   Commodity
# 3     RSP      155  151.66       23507.0              USD       Stock
# 18    RTI    3,300  C0.065         215.0              CAD       Stock
# 16  SCATC       80  171.10       13688.0              NOK       Stock
# 14   SILJ      470   12.38        5814.0              USD        Gold
# 6     SMH       45  269.93       12147.0              USD       Stock
# 21    TMF    3,200   30.42       97341.0              USD       Bonds
# 15   URNM      300   82.51       24753.0              USD   Commodity
# 22    VXX      575   27.06       15560.0              USD  Volatility
