# %%
print ("hello world")
# Out:
# hello world

# %%
import pandas as pd

# %%
df =  pd.read_excel('portfolio_9_22_2021.xlsx')

# %%
df.head()
# Out:
#   Unrealized P&L (%)  Position  Avg Price  Market Value    Last  Change %  \
# 0     15,228 (76.2%)    1700.0     11.763       35224.0   20.72  0.030846
# 1    30,920 (310.0%)   12900.0      0.774       40893.0     3.2  0.028939
# 2     13,079 (83.1%)    3100.0      5.076       28815.0    9.29  0.014738
# 3       2,060 (9.6%)     155.0    138.370       23507.0  151.66  0.013499
# 4      1,935 (23.9%)     150.0     53.901       10020.0   66.81  0.022028
#
#    Daily P&L Financial Instrument  Cost Basis Dividend Date  ...  \
# 0     1054.0         PHOR LSEIOB1     19996.0    2021-09-23  ...
# 1      774.0              GLO TSE      9973.0           NaT  ...
# 2      419.0                OGZPY     15735.0    2022-07-20  ...
# 3      313.0                  RSP     21447.0           NaT  ...
# 4      215.0                  RIO      8085.0    2022-03-03  ...
#
#    Current ratio  Price/Tang.Book Ratio  Price/Book    Market Cap  \
# ...
