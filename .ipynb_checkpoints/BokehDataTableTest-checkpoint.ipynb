# %%
from bokeh.plotting import figure
from bokeh.io import output_file, show
from bokeh.layouts import widgetbox,column,row
from bokeh.models import ColumnDataSource, Range1d, PanTool, ResetTool, HoverTool, Title
from bokeh.models.annotations import BoxAnnotation, Label, LabelSet
from bokeh.models.widgets import DataTable,TableColumn
import pandas

data = pandas.read_csv("rpsl.csv")
    
source = ColumnDataSource(data)

output_file("RockwoodWithDt.html")

#create plot
f=figure()
f.circle(x="East_axis",y="North_Axis", source=source)

#Labels
kiosk= Label(x=237,y=840, text = "ACT Kiosk", background_fill_color='brown')
f.add_layout(kiosk)

ids=LabelSet(x="East_axis",y="North_Axis",text="Tag",source=source)
f.add_layout(ids)

#Title styling
f.title.text= "Rockwood Park Plant Map"
f.title.text_font_size="25px"
f.title.align="center"
f.title.text_color="olive"

f.add_layout(Title(text="               <--- NW 22nd Street --->               ", 
                   align="center", text_color="white", text_font_size= "20px", background_fill_color ="black"),"left")

#Style the tools 
f.tools=[PanTool(),ResetTool()]
hover=HoverTool(tooltips=[("Tag","@Tag"), ("","@Common_Name")])
f.add_tools(hover)

#Plot area Styling
f.plot_width= 470
f.plot_height= 730

#Axis styling
f.xaxis.visible=False
f.yaxis.visible=False

#Axis geometry
f.x_range=Range1d(start=-100,end=840)
f.y_range=Range1d(start=-10,end=1450)

#Spans and boxes
#street=Span(location =-200, dimension='height', line_color='black', line_width=100 )
#f.add_layout(street)
south_fence=BoxAnnotation(bottom=-10, top=0, left=0, fill_color='grey')
f.add_layout(south_fence)

#create dataTable
columns = [
        TableColumn(field="Tag", title="Tag", width=40),
        TableColumn(field="Common_Name", title="Common Name", width=200),
        TableColumn(field="Scientific_Name", title="Scientific Name", width=200),
        TableColumn(field="Origin", title="n/i",width=20),
    ]
data_table = DataTable(source=source, columns=columns, width=500, height=600)
r = (widgetbox(data_table))

show(column(r,f))

# %%
data
# Out:
#     Tag            Common_Name              Scientific_Name Origin  East_axis  \
# 0     1             Poison Ivy       Toxicocendron radicans      n         10
# 1     2       Eastern Redcedar         Juniperus virginiana      n         35
# 2     3      Oakleaf Hydrangea        Hydrangea quercifolia      n        310
# 3     4             Winged Elm                  Ulmus alata      n        355
# 4     5      Bluestem Palmetto                  Sabal minor      n        235
# 5     6      Southern Magnolia         Magnolia Grandiflora      n        200
# 6     7          Loblolly Pine                  Pinus taeda      n        225
# 7     8     Highbush Blueberry         Vaccinium corymbosum      n        315
# 8     9             Common Fig                 Ficus Carica      i        265
# 9    10     Southern Arrowwood          Viburnum dentatatum      n        340
# 10   11              Muscadine           Vitus rotundifolia      n        530
# 11   12            Sour Orange             Citrus aurantium      i        490
# 12   13                 Loquat          Eriobotrya japonica      i        455
# 13   14              Pineapple               Ananas comosus      i        370
# 14   15     Earleaf Greenbrier            Smilax auriculata      n        695
# 15   16      Flowering Dogwood               Cornus florida      n        785
# 16   17       Southern Red Oak              Quercus falcata      n        510
# 17   18            Cabbage Gum        Eucalyptus amplifolia      i        430
# 18   19              Sago-Palm               Cycas revoluta      i        370
# 19   20   Sweet Pinxter Azalea       Rhododendron canescens      n        520
# 20   21           Black Cherry              Prunus serotina      n        565
# 21   22          Yew Plum Pine      Podocarpus macrophyllus      i        670
# 22   23  Carolina Laurelcherry           Prunus caroliniana      n        690
# 23   24            Camphortree          Cinnamomum camphora      i        785
# 24   25            Wild Coffee           Psychotria nervosa      i        610
# 25   26         Flatwoods Plum               Flatwoods Plum      n        555
# 26   27               Rose Gum           Eucalyptis Grandis      i        455
# 27   28   American Beautyberry         Callicarpa americana      n        320
# 28   29         Longleaf Pine               Pinus palustris      n        455
# 29   30             Chinaberry               Melia azedrach      i        435
# 30   31            Crapemyrtle         Lagerstroemia indica      i        445
# 31   32           Summer Grape             Vitis aestivalis      n        640
# 32   33         Eastern Redbud            Cercis canadensis      n        560
# 33   34               Camellia            Camellia japonica      i        660
# 34   35              Gallberry                  Ilex glabra      n        740
# 35   36        Common Persimon         Diospyros virginiana      n        630
# 36   37              Water Oak                Quercus nigra      n        435
# 37   38              Gum Bully      Sideroxylon lanuginosum      n        410
# 38   39           Winged Sumac              Rhus copallinum      n        380
# 39   40              White Oak                 Quercus alba      n        390
# 40   41           Cabbage Palm               Sabal palmetto      n        250
# 41   42            Shumard Oak            Quercus shumardii      n        145
# 42   43     Sandankwa Viburnum           Viburnum suspensum      i        150
# 43   44     Swamp Chestnut Oak            Quercus michauxii      n         75
# 44   45             Sugarberry             Celtis laevigata      n         90
# 45   46       Virginia Creeper  Parthenocissus quinquefolia      n         10
# 46   47             Pindo Palm               Butia capitata      i          0
# 47   48  One-Flowered Hawthorn           Crataegus uniflora      n        190
# 48   49               Sweetgum      Liquidambar styraciflua      n         50
# 49   50                Red Bay              Persea borbonia      n        150
# 50   51                 Mimosa         Albizia julibrissin       i        235
# 51   52  Buddha's Belly Bamboo           Bambusa ventricosa      i        100
# 52   53              White Ash           Fraxinus americana      n        240
#
#     North_Axis  Info_Url  Image_Url
# 0          750       NaN        NaN
# 1          855       NaN        NaN
# 2          930       NaN        NaN
# 3         1000       NaN        NaN
# 4         1010       NaN        NaN
# 5         1030       NaN        NaN
# 6         1030       NaN        NaN
# 7         1060       NaN        NaN
# 8         1120       NaN        NaN
# 9         1410       NaN        NaN
# 10          30       NaN        NaN
# 11        1140       NaN        NaN
# 12        1120       NaN        NaN
# 13         965       NaN        NaN
# 14        1150       NaN        NaN
# 15        1090       NaN        NaN
# 16         840       NaN        NaN
# 17         850       NaN        NaN
# 18         900       NaN        NaN
# 19         880       NaN        NaN
# 20         720       NaN        NaN
# 21         710       NaN        NaN
# 22         680       NaN        NaN
# 23         710       NaN        NaN
# 24         530       NaN        NaN
# 25         405       NaN        NaN
# 26         440       NaN        NaN
# 27         500       NaN        NaN
# 28         440       NaN        NaN
# 29         320       NaN        NaN
# 30         240       NaN        NaN
# 31         360       NaN        NaN
# 32         330       NaN        NaN
# 33         220       NaN        NaN
# 34         130       NaN        NaN
# 35         160       NaN        NaN
# 36         260       NaN        NaN
# 37         175       NaN        NaN
# 38         240       NaN        NaN
# 39         140       NaN        NaN
# 40          20       NaN        NaN
# 41         130       NaN        NaN
# 42          20       NaN        NaN
# 43         100       NaN        NaN
# 44          50       NaN        NaN
# 45         180       NaN        NaN
# 46         190       NaN        NaN
# 47         360       NaN        NaN
# 48         370       NaN        NaN
# 49         470       NaN        NaN
# 50         490       NaN        NaN
# 51         580       NaN        NaN
# 52         710       NaN        NaN
